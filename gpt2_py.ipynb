# %% [markdown]
# <a href="https://colab.research.google.com/github/Ruthikajayaprakash/Rain-prediction-using-machinelearning/blob/main/gpt2_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Libraries Required
# !pip install langchain-huggingface
## For API Calls
# !pip install huggingface_hub
# !pip install transformers
# !pip install accelerate
# !pip install  bitsandbytes
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.8/332.8 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.4/127.4 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 5.5 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...

# %%
## Environment secret keys
from google.colab import userdata
sec_key=userdata.get("HF_TOKEN")
print(sec_key)
# Out:
# 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

# %%
from langchain_huggingface import HuggingFaceEndpoint

# %%
## Environment secret keys
from google.colab import userdata
sec_key=userdata.get("HF_TOKEN")
print(sec_key)
# Out:
# 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

# %%
import os
os.environ["HF_TOKEN"]=sec_key

# %%
repo_id="mistralai/Mistral-7B-Instruct-v0.2"
llm=HuggingFaceEndpoint(repo_id=repo_id,max_length=128,temperature=0.7,token=sec_key)
# Out:
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! token is not default parameter.
#                     token was transferred to model_kwargs.
#                     Please make sure that token is what you intended.

# %%
llm.invoke("What is machine learning")
# Out:
# '? Machine learning is a subset of artificial intelligence (AI) that uses algorithms to enable computers to learn from and make decisions or predictions based on data. In other words, machine learning is a way for computers to learn and improve from experience without being explicitly programmed.\n\nMachine learning algorithms can be broken down into three main categories: supervised learning, unsupervised learning, and reinforcement learning.\n\n1. Supervised learning: In supervised learning, the algorithm is trained on a labeled dataset, meaning that the data includes both input features and the corresponding correct output. The algorithm learns to map input features to outputs by minimizing the difference between its predictions and the correct outputs. Once trained, the algorithm can make predictions on new, unseen data.\n2. Unsupervised learning: In unsupervised learning, the algorithm is trained on an unlabeled dataset, meaning that the data only includes input features without
# ...

# %%
repo_id="mistralai/Mistral-7B-Instruct-v0.3"
llm=HuggingFaceEndpoint(repo_id=repo_id,max_length=128,temperature=0.7,token=sec_key)
# Out:
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! token is not default parameter.
#                     token was transferred to model_kwargs.
#                     Please make sure that token is what you intended.

# %%
llm.invoke("What is Genertaive AI")
# Out:
# '?\n\nGenerative AI is a type of artificial intelligence (AI) that creates new content based on the data it has been trained on. Unlike discriminative AI, which learns to make predictions or classifications based on existing data, generative AI learns the underlying patterns and structures that generate the data itself.\n\nGenerative AI models can be used to generate text, images, music, and even 3D models. For example, a generative AI model can be trained on a large dataset of images of cats, and then generate new images of cats that look realistic and resemble the images in the dataset.\n\nGenerative AI models are typically based on deep learning algorithms, such as recurrent neural networks (RNNs), long short-term memory (LSTM) networks, and generative adversarial networks (GANs). These algorithms are trained on large datasets of examples, and learn to generate new content by predicting the probability of each possible output based on the input data.\n\nGenerative AI has a wide ra
# ...

# %%
from langchain import PromptTemplate, LLMChain

question="Who won the Cricket World Cup in the year 2011?"
template = """Question: {question}
Answer: Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables=["question"])
print(prompt)
# Out:
# input_variables=['question'] template="Question: {question}\nAnswer: Let's think step by step."

# %%
llm_chain=LLMChain(llm=llm,prompt=prompt)
print(llm_chain.invoke(question))
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use RunnableSequence, e.g., `prompt | llm` instead.
#   warn_deprecated(
# {'question': 'Who won the Cricket World Cup in the year 2011?', 'text': " The Cricket World Cup is a tournament held every 4 years. The year 2011 is a year divisible by 4, so it is indeed a year when the World Cup was held. Now, let's see who won that year. The 2011 Cricket World Cup was won by India, who defeated Sri Lanka in the final match. Therefore, India won the Cricket World Cup in the year 2011."}

# %%
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# %%
model_id="gpt2"
model=AutoModelForCausalLM.from_pretrained(model_id)
tokenizer=AutoTokenizer.from_pretrained(model_id)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
pipe=pipeline("text-generation",model=model,tokenizer=tokenizer,max_new_tokens=100)
hf=HuggingFacePipeline(pipeline=pipe)

# %%
hf
# Out:
# HuggingFacePipeline(pipeline=<transformers.pipelines.text_generation.TextGenerationPipeline object at 0x797fe9ecdc60>)

# %%
hf.invoke("what is machine learning ")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 'what is machine learning  ".\n\nWhen an analysis of a data set is conducted as a machine learning approach, some of the characteristics of the data set need to be distinguished and can also be called machine learning:\n\nWe may not have any information about why a particular data set should be selected or whether a particular sample should be included in the analysis. Such information is either unavailable or non-existent. It may be available.\n\nWe may have no information about why a particular model or part of it should be'

# %%
gpu_llm = HuggingFacePipeline.from_model_id(
    model_id="gpt2",
    task="text-generation",
    device=-1,  # Use CPU instead of GPU
    pipeline_kwargs={"max_new_tokens": 100},
)

# %%
from langchain_core.prompts import PromptTemplate

template = """Question: {question}

Answer: Let's think step by step."""
prompt = PromptTemplate.from_template(template)

# %%
chain=prompt|gpu_llm

# %%
question="What is artificial intelligence?"
chain.invoke({"question":question})
# Out:
# "Question: What is artificial intelligence?\n\nAnswer: Let's think step by step. Some people will say it's just a problem with the physical world and some people will say it's because of the Internet. You can see that there is something that's going on in the world and that's not easy to pinpoint it completely but sometimes there is. So there is an interest there from certain people.\n\nBut more than that, there is also a connection with the scientific community because there is an ongoing interest on behalf of scientists. Scientists think that something is happening, right now,"
